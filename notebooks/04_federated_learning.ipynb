# %% [markdown]
# # 04 - Federated Learning
#
# Run Flower-based federated training across simulated merchants.
# Compare FedAvg vs FedProx vs local-only vs centralized.

# %%
# TODO: Implement federated learning experiments
