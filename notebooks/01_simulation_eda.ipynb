# %% [markdown]
# # 01 - Simulation & Exploratory Data Analysis
#
# Generate synthetic perishable goods data and explore demand patterns.

# %%
from meshek_ml.simulation.generator import run_simulation

df = run_simulation(n_merchants=3, start_date='2024-01-01', end_date='2024-06-30', seed=42)
df.head()

# %% [markdown]
# ## Demand Patterns

# %%
from meshek_ml.common.plotting import plot_demand_series

merchant_df = df[df['merchant_id'] == 'merchant_000']
fig = plot_demand_series(merchant_df)
fig.show()
